# %%
import pandas as pd
import matplotlib

# %%
file_location = 'data/national-population.csv'

# %%
# !head data/national-population.csv
# Out:
# realtime_end,realtime_start,value,date
# 2019-04-05,2019-04-05,76094000,1900-01-01
# 2019-04-05,2019-04-05,77584000,1901-01-01
# 2019-04-05,2019-04-05,79163000,1902-01-01
# 2019-04-05,2019-04-05,80632000,1903-01-01
# 2019-04-05,2019-04-05,82166000,1904-01-01
# 2019-04-05,2019-04-05,83822000,1905-01-01
# 2019-04-05,2019-04-05,85450000,1906-01-01
# 2019-04-05,2019-04-05,87008000,1907-01-01
# 2019-04-05,2019-04-05,88710000,1908-01-01

# %%
data = pd.read_csv(file_location, index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#            realtime_end realtime_start     value
# date
# 1900-01-01   2019-04-05     2019-04-05  76094000
# 1901-01-01   2019-04-05     2019-04-05  77584000
# 1902-01-01   2019-04-05     2019-04-05  79163000
# 1903-01-01   2019-04-05     2019-04-05  80632000
# 1904-01-01   2019-04-05     2019-04-05  82166000

# %%
data.drop(['realtime_end', 'realtime_start'], axis=1)
# Out:
#                 value
# date
# 1900-01-01   76094000
# 1901-01-01   77584000
# 1902-01-01   79163000
# 1903-01-01   80632000
# 1904-01-01   82166000
# ...               ...
# 1995-01-01  262803276
# 1996-01-01  265228572
# 1997-01-01  267783607
# 1998-01-01  270248003
# 1999-01-01  272690813
#
# [100 rows x 1 columns]

# %%
#matplotlib inline

# %%
data.plot();
